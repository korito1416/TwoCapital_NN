# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["i_d_simulation","i_g_simulation","i_I_simulation"]
for txt_name in Name:
# File paths
    file_path1 = f'/project/lhansen/Capital_NN/TwoCapital_NN/output/Distortion_result_full_shortrange_128_neurons_32_Agmin_0.12_Agmax_0.12_logxi_-1.0_logxibaseline_-1.0_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Capital_NN/TwoCapital_NN/output/Distortion_result_full_shortrange_128_neurons_32_Agmin_0.12_Agmax_0.14_logxi_-1.0_logxibaseline_-1.0_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Capital_NN/TwoCapital_NN/output/Distortion_result_full_shortrange_128_neurons_32_Agmin_0.12_Agmax_0.16_logxi_-1.0_logxibaseline_-1.0_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'

    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values1 = values1[:600]
    values2 = values2[:600]
    values3 = values3[:600]
    # Indices for the values
    indices1 = range(len(values1))
    indices2 = range(len(values2))
    indices3 = range(len(values3))

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='b', label='Ag range [0.12,0.12]')
    plt.plot(indices2, values2,  color='r', label='Ag range [0.12,0.14]')
    plt.plot(indices3, values3,  color='y', label='Ag range [0.12,0.16]')
    plt.title(f'{txt_name}')
    plt.xlabel('month')
    plt.ylabel('Value')
    plt.legend()
    plt.savefig(f'compare/{txt_name}.png')
    plt.show()

# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["i_d_simulation","i_g_simulation","i_I_simulation"]
for txt_name in Name:
# File paths
    file_path1 = f'/project/lhansen/Capital_NN/TwoCapital_NN/output/Distortion_result_full_shortrange_128_neurons_32_Agmin_0.12_Agmax_0.12_logxi_-2.0_logxibaseline_-2.0_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Capital_NN/TwoCapital_NN/output/Distortion_result_full_shortrange_128_neurons_32_Agmin_0.12_Agmax_0.14_logxi_-2.0_logxibaseline_-2.0_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Capital_NN/TwoCapital_NN/output/Distortion_result_full_shortrange_128_neurons_32_Agmin_0.12_Agmax_0.16_logxi_-2.0_logxibaseline_-2.0_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'

    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values1 = values1[:600]
    values2 = values2[:600]
    values3 = values3[:600]
    # Indices for the values
    indices1 = range(len(values1))
    indices2 = range(len(values2))
    indices3 = range(len(values3))

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='b', label='Ag range [0.12,0.12]')
    plt.plot(indices2, values2,  color='r', label='Ag range [0.12,0.14]')
    plt.plot(indices3, values3,  color='y', label='Ag range [0.12,0.16]')
    plt.title(f'{txt_name}')
    plt.xlabel('month')
    plt.ylabel('Value')
    plt.legend()
    plt.savefig(f'compare/{txt_name}.png')
    plt.show()
