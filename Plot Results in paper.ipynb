# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["Emissions","RD","Id","Ig","TechJumpProb","DmgJumpProb"]
for txt_name in Name:
# File paths 5, -1. -3
 
    file_path1 = f'/project/lhansen/Cap_test/Original_Parameters_small_sigma/output/NewPoster_LR_None_10e-5,10e-5,10e-5,10e-5_full_shortrange_128_neurons_32_Agmin_0.12_Agmax_0.13_logxi_-3.0_logximax_5.0_logxibaseline_-3.0_num_iterations2000000/final_output/pre_tech_pre_damage_shy_pengyu/log_xi_idx_2/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Cap_test/Original_Parameters_small_sigma/output/NewPoster_LR_None_10e-5,10e-5,10e-5,10e-5_full_shortrange_128_neurons_32_Agmin_0.12_Agmax_0.13_logxi_-3.0_logximax_5.0_logxibaseline_-3.0_num_iterations2000000/final_output/pre_tech_pre_damage_shy_pengyu/log_xi_idx_1/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Cap_test/Original_Parameters_small_sigma/output/NewPoster_LR_None_10e-5,10e-5,10e-5,10e-5_full_shortrange_128_neurons_32_Agmin_0.12_Agmax_0.13_logxi_-3.0_logximax_5.0_logxibaseline_-3.0_num_iterations2000000/final_output/pre_tech_pre_damage_shy_pengyu/log_xi_idx_0/{txt_name}.txt'
 

    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values1 = values1[:720]
    values2 = values2[:720]
    values3 = values3[:720]
    # Indices for the values
    indices1 = [x / 12 for x in range(len(values1))]
    indices2 = [x / 12 for x in range(len(values2))]
    indices3 = [x / 12 for x in range(len(values3))]

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='r', label=r'$\xi$ = $\infty$',linewidth=5)
    plt.plot(indices2, values2,  color='g', label=r'$\xi$ = 0.3',linewidth=5)
    plt.plot(indices3, values3,  color='b', label=r'$\xi$ = 0.1',linewidth=5)
    
    if txt_name == "RD":
        plt.title(r'R&D investment as % of Output $(I_k/Y)$',fontsize=16)
    elif txt_name =="Id":
        plt.title(r'Dirty investment $(I_d)$',fontsize=16)
    elif txt_name =="Ig":
        plt.title(r'Green investment $(I_g)$',fontsize=16)
    elif txt_name =="TechJumpProb":
        plt.title('Distorted probability of a Technology jump',fontsize=16)
    elif txt_name =="DmgJumpProb":
        plt.title('Distorted probability of a Damage jump',fontsize=16)
    else:
        plt.title(f'{txt_name}',fontsize=16)
    plt.xlabel('Year',fontsize=16)
    plt.ylabel('Value',fontsize=16)
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["Emissions","RD","Id","Ig","TechJumpProb","DmgJumpProb"]
for txt_name in Name:
# File paths 5, -1. -3
 

    file_path1 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/One_denom_pretrained_dVdY_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations2000000/final_output/pre_tech_pre_damage_shy_MoreAversion/log_xi_idx_3/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/One_denom_pretrained_dVdY_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations2000000/final_output/pre_tech_pre_damage_shy_MoreAversion/log_xi_idx_2/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/One_denom_pretrained_dVdY_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations2000000/final_output/pre_tech_pre_damage_shy_MoreAversion/log_xi_idx_1/{txt_name}.txt'

    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values1 = values1[:720]
    values2 = values2[:720]
    values3 = values3[:720]
    # Indices for the values
    indices1 = [x / 12 for x in range(len(values1))]
    indices2 = [x / 12 for x in range(len(values2))]
    indices3 = [x / 12 for x in range(len(values3))]

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='r', label=r'$\xi$ = $\infty$',linewidth=5)
    plt.plot(indices2, values2,  color='g', label=r'$\xi$ = 0.3',linewidth=5)
    plt.plot(indices3, values3,  color='b', label=r'$\xi$ = 0.1',linewidth=5)
    
    if txt_name == "RD":
        plt.title(r'R&D investment as % of Output $(I_k/Y)$',fontsize=16)
    elif txt_name =="Id":
        plt.title(r'Dirty investment $(I_d)$',fontsize=16)
    elif txt_name =="Ig":
        plt.title(r'Green investment $(I_g)$',fontsize=16)
    elif txt_name =="TechJumpProb":
        plt.title('Distorted probability of a Technology jump',fontsize=16)
    elif txt_name =="DmgJumpProb":
        plt.title('Distorted probability of a Damage jump',fontsize=16)
    else:
        plt.title(f'{txt_name}',fontsize=16)
    plt.xlabel('Year',fontsize=16)
    plt.ylabel('Value',fontsize=16)
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["Emissions","RD","Id","Ig","TechJumpProb","DmgJumpProb"]
for txt_name in Name:
    # File paths 5, -1. -3
    # /project/lhansen/Cap_damage/TwoCapital_NN/output/One_denom_pretrained_dVdY_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations2000000
    file_path1 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/One_denom_pretrained_dVdY_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations2000000/final_output/pre_tech_pre_damage_shy_MoreAversion/log_xi_idx_3/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/One_denom_pretrained_dVdY_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations2000000/final_output/pre_tech_pre_damage_shy_MoreAversion/log_xi_idx_2/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/One_denom_pretrained_dVdY_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations2000000/final_output/pre_tech_pre_damage_shy_MoreAversion/log_xi_idx_1/{txt_name}.txt'
    file_path4 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/One_denom_pretrained_dVdY_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations2000000/final_output/pre_tech_pre_damage_shy_MoreAversion/log_xi_idx_0/{txt_name}.txt'
  
    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values4 = read_values(file_path4)
    values1 = values1[:720]
    values2 = values2[:720]
    values3 = values3[:720]
    values4 = values4[:720]
    # Indices for the values
    indices1 = [x / 12 for x in range(len(values1))]
    indices2 = [x / 12 for x in range(len(values2))]
    indices3 = [x / 12 for x in range(len(values3))]
    indices4 = [x / 12 for x in range(len(values3))]

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='r', label=r'$\xi$ = $\infty$',linewidth=5)
    plt.plot(indices2, values2,  color='g', label=r'$\xi$ = 0.3',linewidth=5)
    plt.plot(indices3, values3,  color='b', label=r'$\xi$ = 0.1',linewidth=5)
    plt.plot(indices4, values4,  color='purple', label=r'$\xi$ = 0.075',linewidth=5)
    
    if txt_name == "RD":
        plt.title(r'R&D investment as % of Output $(I_k/Y)$',fontsize=16)
    elif txt_name =="Id":
        plt.title(r'Dirty investment $(I_d)$',fontsize=16)
    elif txt_name =="Ig":
        plt.title(r'Green investment $(I_g)$',fontsize=16)
    elif txt_name =="TechJumpProb":
        plt.title('Distorted probability of a Technology jump',fontsize=16)
    elif txt_name =="DmgJumpProb":
        plt.title('Distorted probability of a Damage jump',fontsize=16)
    else:
        plt.title(f'{txt_name}',fontsize=16)
    plt.xlabel('Year',fontsize=16)
    plt.ylabel('Value',fontsize=16)
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["Emissions","RD","Id","Ig","TechJumpProb","DmgJumpProb"]
for txt_name in Name:
    # File paths 5, -1. -3
    # Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000
    file_path1 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000/final_output/pre_tech_pre_damage/log_xi_idx_3/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000/final_output/pre_tech_pre_damage/log_xi_idx_2/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000/final_output/pre_tech_pre_damage/log_xi_idx_1/{txt_name}.txt'
    # file_path4 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
  
    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    # values4 = read_values(file_path4)
    values1 = values1[:720]
    values2 = values2[:720]
    values3 = values3[:720]
    # values4 = values4[:720]
    # Indices for the values
    indices1 = [x / 12 for x in range(len(values1))]
    indices2 = [x / 12 for x in range(len(values2))]
    indices3 = [x / 12 for x in range(len(values3))]
    # indices4 = [x / 12 for x in range(len(values3))]

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='r', label=r'$\xi$ = $\infty$',linewidth=5)
    plt.plot(indices2, values2,  color='g', label=r'$\xi$ = 0.3',linewidth=5)
    plt.plot(indices3, values3,  color='b', label=r'$\xi$ = 0.1',linewidth=5)
    # plt.plot(indices4, values4,  color='purple', label=r'$\xi$ = 0.075',linewidth=5)
    
    if txt_name == "RD":
        plt.title(r'R&D investment as % of Output $(I_k/Y)$',fontsize=16)
    elif txt_name =="Id":
        plt.title(r'Dirty investment $(I_d)$',fontsize=16)
    elif txt_name =="Ig":
        plt.title(r'Green investment $(I_g)$',fontsize=16)
    elif txt_name =="TechJumpProb":
        plt.title('Distorted probability of a Technology jump',fontsize=16)
    elif txt_name =="DmgJumpProb":
        plt.title('Distorted probability of a Damage jump',fontsize=16)
    else:
        plt.title(f'{txt_name}',fontsize=16)
    plt.xlabel('Year',fontsize=16)
    plt.ylabel('Value',fontsize=16)
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["Emissions","RD","Id","Ig","TechJumpProb","DmgJumpProb"]
for txt_name in Name:
    # File paths 5, -1. -3
    # Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000
    file_path1 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_3_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600/final_output/pre_tech_pre_damage/log_xi_idx_3/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_3_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600/final_output/pre_tech_pre_damage/log_xi_idx_2/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_3_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600/final_output/pre_tech_pre_damage/log_xi_idx_1/{txt_name}.txt'
    file_path4 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_3_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
  
    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values4 = read_values(file_path4)
    values1 = values1[:720]
    values2 = values2[:720]
    values3 = values3[:720]
    # values4 = values4[:720]
    # Indices for the values
    indices1 = [x / 12 for x in range(len(values1))]
    indices2 = [x / 12 for x in range(len(values2))]
    indices3 = [x / 12 for x in range(len(values3))]
    indices4 = [x / 12 for x in range(len(values3))]

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='r', label=r'$\xi$ = $\infty$',linewidth=5)
    plt.plot(indices2, values2,  color='g', label=r'$\xi$ = 0.3',linewidth=5)
    plt.plot(indices3, values3,  color='b', label=r'$\xi$ = 0.1',linewidth=5)
    plt.plot(indices4, values4,  color='purple', label=r'$\xi$ = 0.075',linewidth=5)
    
    if txt_name == "RD":
        plt.title(r'R&D investment as % of Output $(I_k/Y)$',fontsize=16)
    elif txt_name =="Id":
        plt.title(r'Dirty investment $(I_d)$',fontsize=16)
    elif txt_name =="Ig":
        plt.title(r'Green investment $(I_g)$',fontsize=16)
    elif txt_name =="TechJumpProb":
        plt.title('Distorted probability of a Technology jump',fontsize=16)
    elif txt_name =="DmgJumpProb":
        plt.title('Distorted probability of a Damage jump',fontsize=16)
    else:
        plt.title(f'{txt_name}',fontsize=16)
    plt.xlabel('Year',fontsize=16)
    plt.ylabel('Value',fontsize=16)
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["Emissions","RD","Id","Ig","TechJumpProb","DmgJumpProb"]
for txt_name in Name:
    # File paths 5, -1. -3
    # Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000
    file_path1 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_1.5_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000/final_output/pre_tech_pre_damage/log_xi_idx_3/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_1.5_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000/final_output/pre_tech_pre_damage/log_xi_idx_2/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_1.5_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000/final_output/pre_tech_pre_damage/log_xi_idx_1/{txt_name}.txt'
    file_path4 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/A_g_prime_1.5_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
  
    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values4 = read_values(file_path4)
    values1 = values1[:720]
    values2 = values2[:720]
    values3 = values3[:720]
    # values4 = values4[:720]
    # Indices for the values
    indices1 = [x / 12 for x in range(len(values1))]
    indices2 = [x / 12 for x in range(len(values2))]
    indices3 = [x / 12 for x in range(len(values3))]
    indices4 = [x / 12 for x in range(len(values3))]

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='r', label=r'$\xi$ = $\infty$',linewidth=5)
    plt.plot(indices2, values2,  color='g', label=r'$\xi$ = 0.3',linewidth=5)
    plt.plot(indices3, values3,  color='b', label=r'$\xi$ = 0.1',linewidth=5)
    plt.plot(indices4, values4,  color='purple', label=r'$\xi$ = 0.075',linewidth=5)
    
    if txt_name == "RD":
        plt.title(r'R&D investment as % of Output $(I_k/Y)$',fontsize=16)
    elif txt_name =="Id":
        plt.title(r'Dirty investment $(I_d)$',fontsize=16)
    elif txt_name =="Ig":
        plt.title(r'Green investment $(I_g)$',fontsize=16)
    elif txt_name =="TechJumpProb":
        plt.title('Distorted probability of a Technology jump',fontsize=16)
    elif txt_name =="DmgJumpProb":
        plt.title('Distorted probability of a Damage jump',fontsize=16)
    else:
        plt.title(f'{txt_name}',fontsize=16)
    plt.xlabel('Year',fontsize=16)
    plt.ylabel('Value',fontsize=16)
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["Emissions","RD","Id","Ig","TechJumpProb","DmgJumpProb"]
for txt_name in Name:
    # File paths 5, -1. -3
    # Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000
    file_path1 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.3_Ad_0.12_Ag_0.112857_AgPrime_0.120,0.128,0.136_eta_0.135_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_3/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.3_Ad_0.12_Ag_0.112857_AgPrime_0.120,0.128,0.136_eta_0.135_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_2/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.3_Ad_0.12_Ag_0.112857_AgPrime_0.120,0.128,0.136_eta_0.135_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_1/{txt_name}.txt'
    file_path4 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.3_Ad_0.12_Ag_0.112857_AgPrime_0.120,0.128,0.136_eta_0.135_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
  
    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values4 = read_values(file_path4)
    values1 = values1[:720]
    values2 = values2[:720]
    values3 = values3[:720]
    # values4 = values4[:720]
    # Indices for the values
    indices1 = [x / 12 for x in range(len(values1))]
    indices2 = [x / 12 for x in range(len(values2))]
    indices3 = [x / 12 for x in range(len(values3))]
    indices4 = [x / 12 for x in range(len(values3))]

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='r', label=r'$\xi$ = $\infty$',linewidth=5)
    plt.plot(indices2, values2,  color='g', label=r'$\xi$ = 0.3',linewidth=5)
    plt.plot(indices3, values3,  color='b', label=r'$\xi$ = 0.1',linewidth=5)
    plt.plot(indices4, values4,  color='purple', label=r'$\xi$ = 0.075',linewidth=5)
    
    if txt_name == "RD":
        plt.title(r'R&D investment as % of Output $(I_k/Y)$',fontsize=16)
    elif txt_name =="Id":
        plt.title(r'Dirty investment $(I_d)$',fontsize=16)
    elif txt_name =="Ig":
        plt.title(r'Green investment $(I_g)$',fontsize=16)
    elif txt_name =="TechJumpProb":
        plt.title('Distorted probability of a Technology jump',fontsize=16)
    elif txt_name =="DmgJumpProb":
        plt.title('Distorted probability of a Damage jump',fontsize=16)
    else:
        plt.title(f'{txt_name}',fontsize=16)
    plt.xlabel('Year',fontsize=16)
    plt.ylabel('Value',fontsize=16)
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["Emissions","RD","Id","Ig","TechJumpProb","DmgJumpProb"]
for txt_name in Name:
    # File paths 5, -1. -3
    # Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000
    file_path1 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.3_Ad_0.13_Ag_0.08_AgPrime_0.130,0.139,0.147_eta_0.125_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_3/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.3_Ad_0.13_Ag_0.08_AgPrime_0.130,0.139,0.147_eta_0.125_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_2/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.3_Ad_0.13_Ag_0.08_AgPrime_0.130,0.139,0.147_eta_0.125_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_1/{txt_name}.txt'
    file_path4 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.3_Ad_0.13_Ag_0.08_AgPrime_0.130,0.139,0.147_eta_0.125_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
  
    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values4 = read_values(file_path4)
    values1 = values1[:720]
    values2 = values2[:720]
    values3 = values3[:720]
    # values4 = values4[:720]
    # Indices for the values
    indices1 = [x / 12 for x in range(len(values1))]
    indices2 = [x / 12 for x in range(len(values2))]
    indices3 = [x / 12 for x in range(len(values3))]
    indices4 = [x / 12 for x in range(len(values3))]

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='r', label=r'$\xi$ = $\infty$',linewidth=5)
    plt.plot(indices2, values2,  color='g', label=r'$\xi$ = 0.3',linewidth=5)
    plt.plot(indices3, values3,  color='b', label=r'$\xi$ = 0.1',linewidth=5)
    plt.plot(indices4, values4,  color='purple', label=r'$\xi$ = 0.075',linewidth=5)
    
    if txt_name == "RD":
        plt.title(r'R&D investment as % of Output $(I_k/Y)$',fontsize=16)
    elif txt_name =="Id":
        plt.title(r'Dirty investment $(I_d)$',fontsize=16)
    elif txt_name =="Ig":
        plt.title(r'Green investment $(I_g)$',fontsize=16)
    elif txt_name =="TechJumpProb":
        plt.title('Distorted probability of a Technology jump',fontsize=16)
    elif txt_name =="DmgJumpProb":
        plt.title('Distorted probability of a Damage jump',fontsize=16)
    else:
        plt.title(f'{txt_name}',fontsize=16)
    plt.xlabel('Year',fontsize=16)
    plt.ylabel('Value',fontsize=16)
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["Emissions","RD","Id","Ig","TechJumpProb","DmgJumpProb"]
for txt_name in Name:
    # File paths 5, -1. -3
    # Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000
    file_path1 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.5_Ad_0.13_Ag_0.1_AgPrime_0.128,0.136,0.144_eta_0.175_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_3/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.5_Ad_0.13_Ag_0.1_AgPrime_0.128,0.136,0.144_eta_0.175_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_2/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.5_Ad_0.13_Ag_0.1_AgPrime_0.128,0.136,0.144_eta_0.175_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_1/{txt_name}.txt'
    file_path4 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.5_Ad_0.13_Ag_0.1_AgPrime_0.128,0.136,0.144_eta_0.175_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
  
    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values4 = read_values(file_path4)
    values1 = values1[:720]
    values2 = values2[:720]
    values3 = values3[:720]
    # values4 = values4[:720]
    # Indices for the values
    indices1 = [x / 12 for x in range(len(values1))]
    indices2 = [x / 12 for x in range(len(values2))]
    indices3 = [x / 12 for x in range(len(values3))]
    indices4 = [x / 12 for x in range(len(values3))]

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='r', label=r'$\xi$ = $\infty$',linewidth=5)
    plt.plot(indices2, values2,  color='g', label=r'$\xi$ = 0.3',linewidth=5)
    plt.plot(indices3, values3,  color='b', label=r'$\xi$ = 0.1',linewidth=5)
    plt.plot(indices4, values4,  color='purple', label=r'$\xi$ = 0.075',linewidth=5)
    
    if txt_name == "RD":
        plt.title(r'R&D investment as % of Output $(I_k/Y)$',fontsize=16)
    elif txt_name =="Id":
        plt.title(r'Dirty investment $(I_d)$',fontsize=16)
    elif txt_name =="Ig":
        plt.title(r'Green investment $(I_g)$',fontsize=16)
    elif txt_name =="TechJumpProb":
        plt.title('Distorted probability of a Technology jump',fontsize=16)
    elif txt_name =="DmgJumpProb":
        plt.title('Distorted probability of a Damage jump',fontsize=16)
    else:
        plt.title(f'{txt_name}',fontsize=16)
    plt.xlabel('Year',fontsize=16)
    plt.ylabel('Value',fontsize=16)
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Function to read values from a file
def read_values(file_path):
    values = []
    with open(file_path, 'r') as file:
        for line in file:
            values.append(float(line.strip()))
    return values

Name=["Emissions","RD","Id","Ig","TechJumpProb","DmgJumpProb"]
for txt_name in Name:
    # File paths 5, -1. -3
    # Cap_damage/TwoCapital_NN/output/A_g_prime_1_Delta_0.01_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_128_neurons_32_#HiddenLayer_4_logxi_-3.0_logximax_5.0_num_iterations600000
    file_path1 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.7_Ad_0.13_Ag_0.1086_AgPrime_0.130,0.139,0.147_eta_0.291_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_3/{txt_name}.txt'
    file_path2 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.7_Ad_0.13_Ag_0.1086_AgPrime_0.130,0.139,0.147_eta_0.291_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_2/{txt_name}.txt'
    file_path3 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.7_Ad_0.13_Ag_0.1086_AgPrime_0.130,0.139,0.147_eta_0.291_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_1/{txt_name}.txt'
    file_path4 = f'/project/lhansen/Cap_damage/TwoCapital_NN/output/Z_00.7_Ad_0.13_Ag_0.1086_AgPrime_0.130,0.139,0.147_eta_0.291_LR_piecewiseconstant_10e-5,10e-5,10e-5,10e-5_num_iterations2000000/final_output/pre_tech_pre_damage/log_xi_idx_0/{txt_name}.txt'
  
    # Read values from the files
    values1 = read_values(file_path1)
    values2 = read_values(file_path2)
    values3 = read_values(file_path3)
    values4 = read_values(file_path4)
    values1 = values1[:720]
    values2 = values2[:720]
    values3 = values3[:720]
    # values4 = values4[:720]
    # Indices for the values
    indices1 = [x / 12 for x in range(len(values1))]
    indices2 = [x / 12 for x in range(len(values2))]
    indices3 = [x / 12 for x in range(len(values3))]
    indices4 = [x / 12 for x in range(len(values3))]

    # Plotting the values from both files
    plt.figure(figsize=(10, 6))

    plt.plot(indices1, values1,  color='r', label=r'$\xi$ = $\infty$',linewidth=5)
    plt.plot(indices2, values2,  color='g', label=r'$\xi$ = 0.3',linewidth=5)
    plt.plot(indices3, values3,  color='b', label=r'$\xi$ = 0.1',linewidth=5)
    plt.plot(indices4, values4,  color='purple', label=r'$\xi$ = 0.075',linewidth=5)
    
    if txt_name == "RD":
        plt.title(r'R&D investment as % of Output $(I_k/Y)$',fontsize=16)
    elif txt_name =="Id":
        plt.title(r'Dirty investment $(I_d)$',fontsize=16)
    elif txt_name =="Ig":
        plt.title(r'Green investment $(I_g)$',fontsize=16)
    elif txt_name =="TechJumpProb":
        plt.title('Distorted probability of a Technology jump',fontsize=16)
    elif txt_name =="DmgJumpProb":
        plt.title('Distorted probability of a Damage jump',fontsize=16)
    else:
        plt.title(f'{txt_name}',fontsize=16)
    plt.xlabel('Year',fontsize=16)
    plt.ylabel('Value',fontsize=16)
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  
    plt.legend(fontsize=14)
    plt.show()
